# %%
import dataPreprocessing as dp
import pandas as pd
import warnings
from openpyxl import load_workbook
warnings.filterwarnings("ignore")

# %%
removeList = dp.RemoveList()
encodingList = dp.EncodingList()
calculateAccuracy = dp.CalculateAccuracy()
dataPackage = dp.DataPackage(dataFolderName='data')
dataPackage.readData(needed_num_row=100, gender_col='SubSex')
dataMerged = dataPackage.readData(needed_num_row=100, gender_col='SubSex', maxNum=100,accuracy_threshold=0.8)
dataMerged.to_excel('dataMerged.xlsx', index=False)
dataGenerate = dp.DataGenerate(dataMerged)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 removeList = dp.RemoveList()
#       2 encodingList = dp.EncodingList()
#       3 calculateAccuracy = dp.CalculateAccuracy()
#
# NameError: name 'dp' is not defined

# %%
df = pd.read_excel('dataMerged.xlsx')
dataGenerate = dp.DataGenerate(df)
dataGenerate(verticalAxis='ReactionTime',seperatedPlots='MotionDirection',seperatedLines='TargetPosition',horizontalAxis='ISSame', subNameCol='SubName')
# Out:
# 数据已按照指定列进行分组，multiIndex已展开为单独的列，并保存为Excel文件。
#     SubName   MotionDirection TargetPosition     ISSame  ReactionTime   N
# 0       何雯琦         Clockwise           Down  Different    554.416667  12
# 1       何雯琦         Clockwise           Down    NoMatch    542.375000  24
# 2       何雯琦         Clockwise           Down       Same    535.166667  12
# 3       何雯琦         Clockwise             Up  Different    619.666667  12
# 4       何雯琦         Clockwise             Up    NoMatch    529.083333  24
# ..      ...               ...            ...        ...           ...  ..
# 355     雷文青  CounterClockwise           Down    NoMatch    533.375000  24
# 356     雷文青  CounterClockwise           Down       Same    538.750000  12
# 357     雷文青  CounterClockwise             Up  Different    520.750000  12
# 358     雷文青  CounterClockwise             Up    NoMatch    492.916667  24
# 359     雷文青  CounterClockwise             Up       Same    489.166667  12
#
# [360 rows x 6 columns]
